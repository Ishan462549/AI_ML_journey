# %%
import numpy as np

# %%
a = np.array([1,2,3],dtype='int16')
print(a)
# Out:
# [1 2 3]

# %%
b = np.array([[1,2,4,3],[4,5,6,6]])
print(b)
# Out:
# [[1 2 4 3]
#  [4 5 6 6]]

# %%
#Get dimensions
b.ndim
# Out:
# 2

# %%
# Get shape
a.shape
# Out:
# (3,)

# %%
# Get Type
a.dtype
# Out:
# dtype('int16')

# %%
# Get total size
a.nbytes
# Out:
# 6

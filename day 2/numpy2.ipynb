# %%
import numpy as np

# %%
a = np.array([[2,3,4,5,6,7,8,9],[8,7,6,5,4,3,2,4]])
print(a)
# Out:
# [[2 3 4 5 6 7 8 9]
#  [8 7 6 5 4 3 2 4]]

# %%
# Get specific element [r,c]
print(a[1, 7])
# Out:
# 4

# %%
# Get specific row
a[0,:]
# Out:
# array([2, 3, 4, 5, 6, 7, 8, 9])

# %%
# Get specific colume
a[:,5]
# Out:
# array([7, 3])

# %%
a[0,0:9:1]
# Out:
# array([2, 3, 4, 5, 6, 7, 8, 9])

# %%
a[1,5] = 89
print(a)
a[:,4]=20
print(a)
# Out:
# [[ 2  3  4  5 20  7  8  9]
#  [ 8  7  6  5 20 89  2  4]]
# [[ 2  3  4  5 20  7  8  9]
#  [ 8  7  6  5 20 89  2  4]]

# %%
b = np.array([[[1,2],[3,4]],[[5,6],[7,8]]])
print(b)
# Out:
# [[[1 2]
#   [3 4]]
#
#  [[5 6]
#   [7 8]]]

# %%
print(b[1,0,1])
# Out:
# 6

# %%
b[:,1,0] = [[5,6],[67,9]]
print(b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 b[:,1,0] = [[5,6],[67,9]]
#       2 print(b)
#
# ValueError: setting an array element with a sequence. The requested array would exceed the maximum number of dimension of 1.
